# %% [markdown]
# ### Terms:
# Trip error: how well the correlations between trips’ start and end regions are preserved.
# Length error: measures the error in trip lengths (i.e., distances travelled in each trip).
# Diameter error: diameter of a trajectory is defined as the maximum distance between any pair of its GPS readings.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# store  data for 03-03-1
data = {
    'Error_types': ['Trip error', 'Diameter error', 'Length error'],
    'Epsilon_0.1': [0.528357217283925, 0.5321177767185059, 0.43324354905858364],
    'Epsilon_1': [0.3380505467014452, 0.4294372187702039, 0.32911302149635435],
    'Epsilon_5': [0.007366454968518956, 0.4247667353299599, 0.3193720308549879],
    'Epsilon_10': [0.002228844804712288, 0.4139691985476469, 0.3109217394040632],
    'Epsilon_20': [0.00046252488, 0.42205705481199984, 0.31731831363442065],
    'Epsilon_50': [0.00047037261, 0.4221280666226784, 0.31589618678371456]
    
}

# Create the Pandas DataFrame
df = pd.DataFrame(data)

# Set the 'Category' column as the index
df.set_index('Error_types', inplace=True)

# Display the DataFrame
print(df)
# Out:
#                 Epsilon_0.1  Epsilon_1  Epsilon_5  Epsilon_10  Epsilon_20  \
# Error_types
# Trip error         0.528357   0.338051   0.007366    0.002229    0.000463
# Diameter error     0.532118   0.429437   0.424767    0.413969    0.422057
# Length error       0.433244   0.329113   0.319372    0.310922    0.317318
#
#                 Epsilon_50
# Error_types
# Trip error        0.000470
# Diameter error    0.422128
# Length error      0.315896

# %%
# Plot the line graph
plt.figure(figsize=(10, 6))  # Set the figure size (width, height)

# Plot each line for different categories
for Error_types in df.index:
    plt.plot(df.columns, df.loc[Error_types], marker='o', label=Error_types)

# Set the plot title and axis labels
plt.title('Error Analysis for 03-03-1')
plt.xlabel('Epsilon values')
plt.ylabel('Error')

# Add a legend to the plot
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# store  data for 03-03-2
data = {
    'Error_types': ['Trip error', 'Diameter error', 'Length error'],
    'Epsilon_0.1': [0.5576005522866114, 0.5146176774178828, 0.4289570195390799],
    'Epsilon_1': [0.3410956068467803, 0.45624589092378287, 0.3557405784001708],
    'Epsilon_5': [0.01643828718200765, 0.4452848830894182, 0.34297314712605864],
    'Epsilon_10': [0.010927640958789678, 0.44503010392160336, 0.3431881483004639],
    'Epsilon_20': [0.010235471059739964, 0.45183842402841223, 0.35120343930965187],
    'Epsilon_50': [0.008470987338852622, 0.4430486361103413, 0.3401050644471627]
    
}

# Create the Pandas DataFrame
df = pd.DataFrame(data)

# Set the 'Category' column as the index
df.set_index('Error_types', inplace=True)

# Display the DataFrame
print(df)
# Out:
#                 Epsilon_0.1  Epsilon_1  Epsilon_5  Epsilon_10  Epsilon_20  \
# Error_types
# Trip error         0.557601   0.341096   0.016438    0.010928    0.010235
# Diameter error     0.514618   0.456246   0.445285    0.445030    0.451838
# Length error       0.428957   0.355741   0.342973    0.343188    0.351203
#
#                 Epsilon_50
# Error_types
# Trip error        0.008471
# Diameter error    0.443049
# Length error      0.340105

# %%
# Plot the line graph
plt.figure(figsize=(10, 6))  # Set the figure size (width, height)

# Plot each line for different categories
for Error_types in df.index:
    plt.plot(df.columns, df.loc[Error_types], marker='o', label=Error_types)

# Set the plot title and axis labels
plt.title('Error Analysis for 03-03-2')
plt.xlabel('Epsilon values')
plt.ylabel('Error')

# Add a legend to the plot
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
b
